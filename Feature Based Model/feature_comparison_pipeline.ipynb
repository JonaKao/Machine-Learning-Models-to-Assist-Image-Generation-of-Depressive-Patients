# %% [markdown]
# ### Comparison

# %% [markdown]
# The Purpose of this Notebook is to group the existing patient data into 4 groups based on their PHQ score, this grouping aims to analyze what facial actions are most correlated to sever depression, i.e high PHQ, and which AUs are most 'irrelevant'. To do this, we want to aggregate the values, once we have created our groupings, as well as calculate the ranges on which the AUs exist.

# %%
import os, json, pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import (
    roc_auc_score, average_precision_score, accuracy_score,
    brier_score_loss, classification_report, confusion_matrix,
    f1_score, roc_curve, auc, precision_recall_curve
)
from sklearn.calibration import calibration_curve

# %% [markdown]
# This first code snippet will thus serve to organize the patients, and their corresponding data, into the groupings addressing the severity of their symptoms. To do this, we will construct an automated crawler which will use the metadata_mapped.csv file to match PHQ to patients and then the patients into the new groups we have declared.

# %%
def group1:
    if PHQ >= 0 && PHQ <= 10
